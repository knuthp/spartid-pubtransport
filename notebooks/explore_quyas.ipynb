# %% [markdown]
# # National Stop Place Register - Quays
# * API - <https://developer.entur.org/stop-places-v1-read>
#
#
# Quays does not have a a geographic name. It does not have a mapping to a stop-place with a name.
#
# Hence, quays only has limited use alone.

# %%
import pandas as pd
import requests

# %%
base_url = "https://api.entur.io/stop-places/v1/read"

# %% [markdown]
# ## All quays
#
# ```json
# {
#   "id": "NSR:Quay:10",
#   "changed": "2018-05-24T09:15:50.958+02:00",
#   "modification": "NEW",
#   "version": "4",
#   "status_BasicModificationDetailsGroup": "ACTIVE",
#   "publication": "PUBLIC",
#   "keyList": {
#     "keyValue": [
#       {
#         "key": "grails-platformId",
#         "value": "6175"
#       },
#       {
#         "key": "uicCode",
#         "value": "7600743"
#       },
#       {
#         "key": "imported-id",
#         "value": "NSB:Quay:007600743,NSB:Quay:076007431,FLT:Quay:7600743,NSB:Quay:0076007431"
#       },
#       {
#         "key": "tpsiId",
#         "value": "760074301"
#       }
#     ]
#   },
#   "privateCode": {
#     "value": "1"
#   },
#   "centroid": {
#     "modification": "NEW",
#     "status_BasicModificationDetailsGroup": "ACTIVE",
#     "publication": "PUBLIC",
#     "location": {
#       "longitude": 9.537064,
#       "latitude": 61.772302
#     }
#   },
#   "publicCode": "1"
# }
# ```

# %%
df_quays_raw = pd.read_json(f"{base_url}/quays?count=10000").convert_dtypes(dtype_backend="pyarrow")
df_quays_raw
# Out:
#                    id                        changed modification  version  \
# 0          NSR:Quay:1  2023-01-11T09:41:59.069+01:00          NEW       33
# 1         NSR:Quay:10  2018-05-24T09:15:50.958+02:00          NEW        4
# 2        NSR:Quay:100   2018-05-14T15:17:57.48+02:00          NEW        5
# 3       NSR:Quay:1000  2023-04-06T12:40:34.563+02:00          NEW       15
# 4      NSR:Quay:10000  2021-02-11T14:57:02.972+01:00          NEW        2
# ...               ...                            ...          ...      ...
# 9995  NSR:Quay:109026  2024-03-07T13:59:56.477+01:00          NEW        2
# 9996  NSR:Quay:109027  2024-03-07T13:59:56.475+01:00          NEW        2
# 9997  NSR:Quay:109028  2024-03-07T13:59:56.473+01:00          NEW        2
# 9998  NSR:Quay:109029  2024-03-07T13:59:56.479+01:00          NEW        2
# 9999   NSR:Quay:10903  2022-02-18T10:35:57.945+01:00          NEW        3
#
#      status_BasicModificationDetailsGroup publication  \
# 0                                  ACTIVE      PUBLIC
# 1                                  ACTIVE      PUBLIC
# 2                                  ACTIVE      PUBLIC
# 3                                  ACTIVE      PUBLIC
# 4                                  ACTIVE      PUBLIC
# ...                                   ...         ...
# 9995                               ACTIVE      PUBLIC
# 9996                               ACTIVE      PUBLIC
# 9997                               ACTIVE      PUBLIC
# 9998                               ACTIVE      PUBLIC
# 9999                               ACTIVE      PUBLIC
#
#                                                 keyList      privateCode  \
# 0     {'keyValue': [{'key': 'uicCode', 'value': '760...  {'value': '30'}
# 1     {'keyValue': [{'key': 'grails-platformId', 'va...   {'value': '1'}
# 2     {'keyValue': [{'key': 'grails-platformId', 'va...   {'value': '1'}
# 3     {'keyValue': [{'key': 'grails-platformId', 'va...   {'value': '4'}
# 4     {'keyValue': [{'key': 'imported-id', 'value': ...   {'value': '2'}
# ...                                                 ...              ...
# 9995             {'keyValue': [{'key': 'imported-id'}]}               {}
# 9996             {'keyValue': [{'key': 'imported-id'}]}               {}
# 9997             {'keyValue': [{'key': 'imported-id'}]}               {}
# 9998             {'keyValue': [{'key': 'imported-id'}]}               {}
# 9999  {'keyValue': [{'key': 'imported-id', 'value': ...   {'value': '1'}
#
#                                                centroid  \
# 0     {'modification': 'NEW', 'status_BasicModificat...
# 1     {'modification': 'NEW', 'status_BasicModificat...
# 2     {'modification': 'NEW', 'status_BasicModificat...
# 3     {'modification': 'NEW', 'status_BasicModificat...
# 4     {'modification': 'NEW', 'status_BasicModificat...
# ...                                                 ...
# 9995  {'modification': 'NEW', 'status_BasicModificat...
# 9996  {'modification': 'NEW', 'status_BasicModificat...
# 9997  {'modification': 'NEW', 'status_BasicModificat...
# 9998  {'modification': 'NEW', 'status_BasicModificat...
# 9999  {'modification': 'NEW', 'status_BasicModificat...
#
#                                 accessibilityAssessment  \
# 0     {'id': 'NSR:AccessibilityAssessment:60511', 'm...
# 1                                                   NaN
# 2                                                   NaN
# 3     {'id': 'NSR:AccessibilityAssessment:63719', 'm...
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#                                         placeEquipments publicCode  \
# 0     {'id': 'NSR:PlaceEquipment:70362', 'modificati...       <NA>
# 1                                                   NaN          1
# 2                                                   NaN          1
# 3                                                   NaN          4
# 4                                                   NaN       <NA>
# ...                                                 ...        ...
# 9995                                                NaN          9
# 9996                                                NaN          6
# 9997                                                NaN          2
# 9998                                                NaN         11
# 9999                                                NaN       <NA>
#
#       compassBearing created description boardingPositions
# 0               <NA>    <NA>         NaN               NaN
# 1               <NA>    <NA>         NaN               NaN
# 2               <NA>    <NA>         NaN               NaN
# 3               <NA>    <NA>         NaN               NaN
# 4                 79    <NA>         NaN               NaN
# ...              ...     ...         ...               ...
# 9995            <NA>    <NA>         NaN               NaN
# 9996            <NA>    <NA>         NaN               NaN
# 9997            <NA>    <NA>         NaN               NaN
# 9998            <NA>    <NA>         NaN               NaN
# 9999             157    <NA>         NaN               NaN
#
# [10000 rows x 16 columns]

# %%
df_quays_raw.centroid.str.get("status_BasicModificationDetailsGroup").value_counts()
# Out:
# centroid
# ACTIVE    10000
# Name: count, dtype: int64

# %%
(df_quays_raw
    .assign(
        latitude=df_quays_raw.centroid.str["location"].str["latitude"],
        logitude=df_quays_raw.centroid.str["location"].str["longitude"],
        changed=pd.to_datetime(df_quays_raw.changed, format="ISO8601", utc=True),
        # privateCode=df_quays_raw.privateCode.str.get("value").astype("int64[pyarrow]"),
    )
).dtypes
# Out:
# id                                          string[pyarrow]
# changed                                 datetime64[ns, UTC]
# modification                                string[pyarrow]
# version                                      int64[pyarrow]
# status_BasicModificationDetailsGroup        string[pyarrow]
# publication                                 string[pyarrow]
# keyList                                              object
# privateCode                                          object
# centroid                                             object
# accessibilityAssessment                              object
# placeEquipments                                      object
# publicCode                                  string[pyarrow]
# compassBearing                               int64[pyarrow]
# created                                     string[pyarrow]
# description                                          object
# boardingPositions                                    object
# latitude                                            float64
# logitude                                            float64
# dtype: object

# %% [markdown]
# ## One quay on Stop Place

# %%
id = "NSR:Quay:10330" # Ellingsrudaasen

# %%
pd.read_json(f"{base_url}/quays/{id}")
# Out:
#                                                   id  \
# keyValue                              NSR:Quay:10330
# value                                 NSR:Quay:10330
# lang                                  NSR:Quay:10330
# modification                          NSR:Quay:10330
# status_BasicModificationDetailsGroup  NSR:Quay:10330
# publication                           NSR:Quay:10330
# location                              NSR:Quay:10330
# id                                    NSR:Quay:10330
# version                               NSR:Quay:10330
# mobilityImpairedAccess                NSR:Quay:10330
# limitations                           NSR:Quay:10330
#
#                                                             changed  \
# keyValue                              2021-11-29T11:13:22.226+01:00
# value                                 2021-11-29T11:13:22.226+01:00
# lang                                  2021-11-29T11:13:22.226+01:00
# modification                          2021-11-29T11:13:22.226+01:00
# status_BasicModificationDetailsGroup  2021-11-29T11:13:22.226+01:00
# publication                           2021-11-29T11:13:22.226+01:00
# location                              2021-11-29T11:13:22.226+01:00
# id                                    2021-11-29T11:13:22.226+01:00
# version                               2021-11-29T11:13:22.226+01:00
# mobilityImpairedAccess                2021-11-29T11:13:22.226+01:00
# limitations                           2021-11-29T11:13:22.226+01:00
#
#                                      modification  version  \
# keyValue                                      NEW       10
# value                                         NEW       10
# lang                                          NEW       10
# modification                                  NEW       10
# status_BasicModificationDetailsGroup          NEW       10
# publication                                   NEW       10
# location                                      NEW       10
# id                                            NEW       10
# version                                       NEW       10
# mobilityImpairedAccess                        NEW       10
# limitations                                   NEW       10
#
#                                      status_BasicModificationDetailsGroup  \
# keyValue                                                           ACTIVE
# value                                                              ACTIVE
# lang                                                               ACTIVE
# modification                                                       ACTIVE
# status_BasicModificationDetailsGroup                               ACTIVE
# publication                                                        ACTIVE
# location                                                           ACTIVE
# id                                                                 ACTIVE
# version                                                            ACTIVE
# mobilityImpairedAccess                                             ACTIVE
# limitations                                                        ACTIVE
#
#                                      publication  \
# keyValue                                  PUBLIC
# value                                     PUBLIC
# lang                                      PUBLIC
# modification                              PUBLIC
# status_BasicModificationDetailsGroup      PUBLIC
# publication                               PUBLIC
# location                                  PUBLIC
# id                                        PUBLIC
# version                                   PUBLIC
# mobilityImpairedAccess                    PUBLIC
# limitations                               PUBLIC
#
#                                                                                 keyList  \
# keyValue                              [{'key': 'imported-id', 'value': 'RUT:Quay:ELÅ...
# value                                                                               NaN
# lang                                                                                NaN
# modification                                                                        NaN
# status_BasicModificationDetailsGroup                                                NaN
# publication                                                                         NaN
# location                                                                            NaN
# id                                                                                  NaN
# version                                                                             NaN
# mobilityImpairedAccess                                                              NaN
# limitations                                                                         NaN
#
#                                           description  privateCode  \
# keyValue                                          NaN          NaN
# value                                 Retning sentrum          2.0
# lang                                              nor          NaN
# modification                                      NaN          NaN
# status_BasicModificationDetailsGroup              NaN          NaN
# publication                                       NaN          NaN
# location                                          NaN          NaN
# id                                                NaN          NaN
# version                                           NaN          NaN
# mobilityImpairedAccess                            NaN          NaN
# limitations                                       NaN          NaN
#
#                                                                              centroid  \
# keyValue                                                                          NaN
# value                                                                             NaN
# lang                                                                              NaN
# modification                                                                      NEW
# status_BasicModificationDetailsGroup                                           ACTIVE
# publication                                                                    PUBLIC
# location                              {'longitude': 10.915676, 'latitude': 59.936623}
# id                                                                                NaN
# version                                                                           NaN
# mobilityImpairedAccess                                                            NaN
# limitations                                                                       NaN
#
#                                                                 accessibilityAssessment  \
# keyValue                                                                            NaN
# value                                                                               NaN
# lang                                                                                NaN
# modification                                                                        NEW
# status_BasicModificationDetailsGroup                                             ACTIVE
# publication                                                                      PUBLIC
# location                                                                            NaN
# id                                                    NSR:AccessibilityAssessment:63747
# version                                                                               3
# mobilityImpairedAccess                                                          UNKNOWN
# limitations                           {'accessibilityLimitation': {'id': '161770', '...
#
#                                       publicCode
# keyValue                                       2
# value                                          2
# lang                                           2
# modification                                   2
# status_BasicModificationDetailsGroup           2
# publication                                    2
# location                                       2
# id                                             2
# version                                        2
# mobilityImpairedAccess                         2
# limitations                                    2

# %%
resp = requests.get(f"{base_url}/quays/{id}")

resp.json()
# Out:
# {'id': 'NSR:Quay:10330',
#  'changed': '2021-11-29T11:13:22.226+01:00',
#  'modification': 'NEW',
#  'version': '10',
#  'status_BasicModificationDetailsGroup': 'ACTIVE',
#  'publication': 'PUBLIC',
#  'keyList': {'keyValue': [{'key': 'imported-id',
#     'value': 'RUT:Quay:ELÅ2,RUT:Quay:301163002,RUT:Quay:0301163002'}]},
#  'description': {'value': 'Retning sentrum', 'lang': 'nor'},
#  'privateCode': {'value': '2'},
#  'centroid': {'modification': 'NEW',
#   'status_BasicModificationDetailsGroup': 'ACTIVE',
#   'publication': 'PUBLIC',
#   'location': {'longitude': 10.915676, 'latitude': 59.936623}},
#  'accessibilityAssessment': {'id': 'NSR:AccessibilityAssessment:63747',
#   'modification': 'NEW',
#   'version': '3',
#   'status_BasicModificationDetailsGroup': 'ACTIVE',
#   'publication': 'PUBLIC',
#   'mobilityImpairedAccess': 'UNKNOWN',
#   'limitations': {'accessibilityLimitation': {'id': '161770',
#     'modification': 'NEW',
#     'version': '3',
#     'status_BasicModificationDetailsGroup': 'ACTIVE',
#     'publication': 'PUBLIC',
#     'wheelchairAccess': 'UNKNOWN',
#     'stepFreeAccess': 'UNKNOWN',
#     'escalatorFreeAccess': 'UNKNOWN',
#     'liftFreeAccess': 'UNKNOWN',
#     'audibleSignalsAvailable': 'UNKNOWN'}}},
#  'publicCode': '2'}
