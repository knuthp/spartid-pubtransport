# %%
from pathlib import Path

import pandas as pd
import sqlalchemy
from sqlalchemy import text

# %%
SQLALCHEMY_DATABASE_URI = (
    "postgresql://postgres:postgres@ptest:9202/spartid_pubtransport"
)
con = sqlalchemy.create_engine(SQLALCHEMY_DATABASE_URI)

# %% [markdown]
# ## Explore data in postgres
# ### Lets peek into table data

# %%
pd.read_sql(
    """
    SELECT *
    FROM "VEHICLE_MONITORING"
    LIMIT 5;
    """,
    dtype_backend="pyarrow",
    con=con,
)
# Out:
#    index DataFrameRef                             DatedVehicleJourneyRef  \
# 0      0   2024-04-29  AKT:ServiceJourney:235_1_1_11_16_52800_54060_1...
# 1      1   2024-04-29        MOR:ServiceJourney:702_104_9150000002865750
# 2      2   2024-04-29        TRO:ServiceJourney:100_240305165461785_1006
# 3      3   2024-04-29       KOL:ServiceJourney:1008_240129074292598_2002
# 4      4   2024-04-29               NSB:ServiceJourney:2814-SKI_159528-R
#
#                RecordedAtTime         LineRef VehicleMode            Delay  \
# 0         2024-04-29 05:27:41    AKT:Line:235         bus     119000000000
# 1         2024-04-29 05:27:42    MOR:Line:702         bus                0
# 2         2024-04-29 02:05:32  TRO:Line:1_100         bus  -28769000000000
# 3         2024-04-29 05:27:37            1008         bus     113000000000
# 4  2024-04-29 05:27:24.647000     NSB:Line:L2        rail                0
#
#     Latitude  Longitude
# 0   58.10526   7.064187
# 1  62.744804   7.219861
# 2    69.1342  18.576628
# 3  58.942106   5.682355
# 4  59.718678  10.834435

# %% [markdown]
# ### Lets look at table data types

# %%
pd.read_sql(
    """
    SELECT column_name, data_type
    FROM information_schema.columns
    WHERE table_name = 'VEHICLE_MONITORING'
    """,
    dtype_backend="pyarrow",
    con=con,
)
# Out:
#               column_name                    data_type
# 0                   index                       bigint
# 1          RecordedAtTime  timestamp without time zone
# 2                   Delay                       bigint
# 3                Latitude             double precision
# 4               Longitude             double precision
# 5            DataFrameRef            character varying
# 6  DatedVehicleJourneyRef            character varying
# 7             VehicleMode            character varying
# 8                 LineRef            character varying

# %%
with con.connect() as connection:
    connection.execute(
        text(
            """
        CREATE INDEX IF NOT EXISTS data_frame_ref_index ON "VEHICLE_MONITORING" ("DataFrameRef");
        """
        )
    )
    connection.commit()

# %%
with pd.option_context("display.max_colwidth", 0):
    display(
        pd.read_sql(
            """
        SELECT COUNT(*), avg("Latitude") as avg_lat, avg("Longitude") as avg_long
        FROM "VEHICLE_MONITORING"
        WHERE "DataFrameRef" = '2024-05-26';
        """,
            dtype_backend="pyarrow",
            con=con,
        )
    )
# Out:
#      count    avg_lat  avg_long
# 0  1392123  61.709367  9.91075

# %%
with pd.option_context("display.max_colwidth", 0):
    display(
        pd.read_sql(
            """
        SELECT "DataFrameRef", COUNT(*), avg("Latitude") as avg_lat, avg("Longitude") as avg_long
        FROM "VEHICLE_MONITORING"
        GROUP BY "DataFrameRef";
        """,
            dtype_backend="pyarrow",
            con=con,
        )
    )
# Out:
#             DataFrameRef    count    avg_lat   avg_long
# 0    2024-04-23           213      62.739834  7.193296
# 1    2024-04-23T04:00:00  185343   67.838985  15.134614
# 2    2024-04-24T04:00:00  493475   67.43458   14.627298
# 3    2024-04-25T04:00:00  292780   67.468067  14.965992
# 4    2024-04-26           1931     62.808049  7.630055
# ..          ...            ...           ...       ...
# 401  2025-05-03           1767668  61.376451  9.001037
# 402  2025-05-04           1301709  61.718429  9.319113
# 403  2025-05-05           3377791  61.676393  9.530975
# 404  2025-05-06           295701   62.085573  10.443542
# 405  <NA>                 2385     58.961568  5.718481
#
# [406 rows x 4 columns]

# %%
with pd.option_context("display.max_colwidth", 0):
    display(
        pd.read_sql(
            """
        SELECT DISTINCT("DataFrameRef")
        FROM "VEHICLE_MONITORING";
        """,
            dtype_backend="pyarrow",
            con=con,
        )
    )
# Out:
#             DataFrameRef
# 0    2024-04-23
# 1    2024-04-23T04:00:00
# 2    2024-04-24T04:00:00
# 3    2024-04-25T04:00:00
# 4    2024-04-26
# ..          ...
# 401  2025-05-03
# 402  2025-05-04
# 403  2025-05-05
# 404  2025-05-06
# 405  <NA>
#
# [406 rows x 1 columns]

# %%
df_raw = pd.read_sql(
    """
    SELECT DATE("DataFrameRef"), COUNT(DATE("DataFrameRef"))
    FROM "VEHICLE_MONITORING"
    GROUP BY DATE("DataFrameRef")
    LIMIT 1000;
    """,
    dtype_backend="pyarrow",
    con=con,
)
df_raw

# %%
Path("../data/vehicle_monitoring/").mkdir(parents=True, exist_ok=True)
df_raw.to_parquet(
    f"../data/vehicle_monitoring/{day}.parquet",
    index=False,
)

# %%
df_raw = pd.read_parquet(
    f"../data/vehicle_monitoring/{day}.parquet", dtype_backend="pyarrow"
)
len(df_raw)
# Out:
# 1746380

# %%
(
    df_raw.groupby("DatedVehicleJourneyRef")
    .agg(
        {
            "index": ("count"),
            "RecordedAtTime": ("min", "max", "nunique"),
        }
    )
    # .sort_values(("index", "count"), ascending=False)
    .sort_values(("RecordedAtTime", "nunique"), ascending=False)
    .plot(y=[("index", "count"), ("RecordedAtTime", "nunique")], rot=90)
)
# Out:
# <Axes: xlabel='DatedVehicleJourneyRef'>

# %%
df = df_raw.drop_duplicates(subset=["DatedVehicleJourneyRef", "RecordedAtTime"])
df
# Out:
#          index DataFrameRef                        DatedVehicleJourneyRef  \
# 0         1433   2024-05-17  KOL:ServiceJourney:1004_240129074289379_2120
# 1         1451   2024-05-17  KOL:ServiceJourney:1004_240129074289476_2121
# 2         1487   2024-05-17  KOL:ServiceJourney:1043_240129074280825_1064
# 3         1533   2024-05-17  KOL:ServiceJourney:2010_240129074284447_1043
# 4         1543   2024-05-17  KOL:ServiceJourney:1011_240207094368481_1076
# ...        ...          ...                                           ...
# 1745648   1015   2024-05-17    OST:ServiceJourney:115_231204075611925_610
# 1745667   1015   2024-05-17    OST:ServiceJourney:115_231204075611925_610
# 1745686   1015   2024-05-17    OST:ServiceJourney:115_231204075611925_610
# 1745705   1017   2024-05-17    OST:ServiceJourney:115_231204075611925_610
# 1745724   1018   2024-05-17    OST:ServiceJourney:115_231204075611925_610
#
#                      RecordedAtTime         LineRef VehicleMode  \
# 0               2024-05-16 22:30:56            1004         bus
# 1               2024-05-16 22:30:55            1004         bus
# 2               2024-05-16 22:26:58            1043         bus
# 3               2024-05-16 22:30:55            2010         bus
# 4               2024-05-16 22:30:55            1011         bus
# ...                             ...             ...         ...
# 1745648  2024-05-20 15:11:24.299371  OST:Line:1_115     unknown
# 1745667  2024-05-20 15:12:30.490427  OST:Line:1_115     unknown
# 1745686  2024-05-20 15:13:30.318891  OST:Line:1_115     unknown
# 1745705  2024-05-20 15:14:31.371933  OST:Line:1_115     unknown
# 1745724  2024-05-20 15:15:32.367896  OST:Line:1_115     unknown
#
#                         Delay   Latitude  Longitude
# 0                -65000000000  58.966895   5.734501
# 1                204000000000  58.908489     5.7287
# 2        -9223372036854775808  58.901519   5.707784
# 3                148000000000  58.914057    5.85207
# 4                173000000000  59.004345   5.620505
# ...                       ...        ...        ...
# 1745648       260066000000000  59.230637  10.980172
# 1745667       260127000000000  59.230645  10.980192
# 1745686       260188000000000  59.230645  10.980192
# 1745705       260249000000000  59.230655  10.980222
# 1745724       260310000000000  59.230647   10.98021
#
# [936436 rows x 9 columns]

# %%
(
    df.sort_values(["DatedVehicleJourneyRef", "RecordedAtTime"])
    .head(1000)
    .groupby("DatedVehicleJourneyRef")
    .plot(x="Latitude", y="Longitude")
)

# %%
df_raw.drop_duplicates(subset=["DatedVehicleJourneyRef", "RecordedAtTime"])
